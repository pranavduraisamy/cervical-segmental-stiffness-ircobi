# %% [markdown]
# ## Initialization

# %%
import os
from pathlib import Path
import xarray as xr
import holoviews as hv
from holoviews import opts
import matplotlib.pyplot as plt
import pandas as pd
from great_tables import GT, md, html, loc, style
import helper
import warnings
plt.style.use('default')
plt.rcParams['font.family']='Times New Roman'
plt.rcParams['font.size']=12
warnings.simplefilter("ignore")
hv.extension('bokeh')
_p=Path(os.getcwd())
p=_p.parent
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="be60d058-749f-410b-abf0-3cc2d05ef81f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
helper.extract_lower_cervical()
ds=xr.open_dataset(p/'processed-data/master.nc')
ds.close()
df=pd.read_csv(p/'processed-data/master.csv')

wnkd=pd.read_csv(p.parent/'data/Winkelstein2000/clean-data/a01-specimen-info.csv')
wnkf=pd.read_csv(p.parent/'data/Winkelstein2000/clean-data/a09-flexion-moment.csv')
wnke=pd.read_csv(p.parent/'data/Winkelstein2000/clean-data/a08-extension-moment.csv')
wnkd['Extension']=wnke.A2
wnkd['Flexion']=wnkf.A2
wnkd=wnkd.dropna().reset_index(drop=True)
wnkd['BMI']=wnkd['Weight (kg)']/((wnkd['Height (cm)']/100)**2)
wnkd34=wnkd[wnkd['Cervical Level']=='C3-C4'].reset_index(drop=True)
wnkd56=wnkd[wnkd['Cervical Level']=='C5-C6'].reset_index(drop=True)
# Out:
# saved: master.csv
# saved: master.nc

# %% [markdown]
# # Plots and Tables for Nightingale2002+Nightingale2007

# %% [markdown]
# ## Count Table

# %%
c=pd.DataFrame()
c['l']=['C3C4', 'C4C5', 'C5C6', 'C6C7']
c['mf']=df[(df['sex']=='Male')&(df['loading']=='Flexion')].value_counts('level',sort=False).values
c['me']=df[(df['sex']=='Male')&(df['loading']=='Extension')].value_counts('level',sort=False).values
c['ff']=df[(df['sex']=='Female')&(df['loading']=='Flexion')].value_counts('level',sort=False).values
c['fe']=df[(df['sex']=='Female')&(df['loading']=='Extension')].value_counts('level',sort=False).values
(
    GT(c,rowname_col='l')
    .tab_spanner(label=md("*Male*"), columns=["mf", "me"])
    .tab_spanner(label=md("*Female*"), columns=["ff", "fe"])
    .tab_header(
        title=html("Data Count - Nightingale ")
    )
    .cols_label(mf="Flexion", me="Extension",ff="Flexion", fe="Extension")
    .tab_stubhead('Cervical Level')
    .fmt_integer(columns=["mf", "me"], use_seps=False)
    .tab_source_note(source_note="Only Lower Cervical Flexibility Tests' Data")
    .tab_style(
        style=style.fill(color="lightcyan"),
        locations=loc.body(columns=["mf","me"]),
    )
    .tab_style(
        style=style.fill(color="mistyrose"),
        locations=loc.body(columns=["ff","fe"]),
    )
)
# Out:
# GT(_tbl_data=      l  mf  me  ff  fe
# 0  C3C4   1   1  11  11
# 1  C4C5   6  11   1   1
# 2  C5C6   1   1  11  11
# ...

# %% [markdown]
# ## Violins 1 - Distribution of Rotation grouped by Sample_id & Sex

# %%
hv.BoxWhisker((ds.sex.values,ds.sample_id.values,ds.r3.values),['Sex', 'Sample_id'], 'Rotation at 3Nm').opts(height=500, show_legend=False, width=1100,box_fill_color=hv.dim('Sample_id').str(),cmap='bmy')
# Out:
# :BoxWhisker   [Sex,Sample_id]   (Rotation at 3Nm)

# %% [markdown]
# ## Violins 2 - Distribution of Rotation grouped by Loading mode & Sex

# %%
hv.BoxWhisker((ds.sex.values,ds.loading.values,ds.r3.values),['Sex', 'Loading'], 'Rotation at 3Nm').opts(height=500, show_legend=False, width=400, box_fill_color=hv.dim('Sex').str(), cmap='cwr_r', backend_opts={"plot.toolbar.autohide": True})
# Out:
# :BoxWhisker   [Sex,Loading]   (Rotation at 3Nm)

# %% [markdown]
# # Plots for Winkelstein2000

# %%
fig,ax=plt.subplots(1,3,figsize=(12,4),sharey=True)
fig.tight_layout()

ax[0].scatter(wnkd34['Weight (kg)'],wnkd34.Extension,zorder=1,s=60,lw=2,marker='o',edgecolors='darkslategrey',facecolor='None',label='C3C4 Extension')
ax[0].scatter(wnkd56['Weight (kg)'],wnkd56.Extension,zorder=2,s=60,lw=2,marker='D',edgecolors='lightslategrey',facecolor='None',label='C5C6 Extension')
ax[0].scatter(wnkd34['Weight (kg)'],wnkd34.Flexion,zorder=3,s=60,lw=2,marker='o',edgecolors='darkviolet',facecolor='None',label='C3C4 Flexion')
ax[0].scatter(wnkd56['Weight (kg)'],wnkd56.Flexion,zorder=4,s=60,lw=2,marker='D',edgecolors='violet',facecolor='None',label='C5C6 Flexion')
ax[0].set_xlabel('Weight (kg)')
ax[0].set_ylabel('Rotation Angle')
ax[0].set_title('Weight vs Rotation Angle')

ax[1].scatter(wnkd34['Height (cm)'],wnkd34.Extension,zorder=1,s=60,lw=2,marker='o',edgecolors='darkslategrey',facecolor='None',label='C3C4 Extension')
ax[1].scatter(wnkd56['Height (cm)'],wnkd56.Extension,zorder=2,s=60,lw=2,marker='D',edgecolors='lightslategrey',facecolor='None',label='C5C6 Extension')
ax[1].scatter(wnkd34['Height (cm)'],wnkd34.Flexion,zorder=3,s=60,lw=2,marker='o',edgecolors='darkviolet',facecolor='None',label='C3C4 Flexion')
ax[1].scatter(wnkd56['Height (cm)'],wnkd56.Flexion,zorder=4,s=60,lw=2,marker='D',edgecolors='violet',facecolor='None',label='C5C6 Flexion')
ax[1].set_xlabel('Height (cm)')
ax[1].set_title('Height vs Rotation Angle')

ax[2].scatter(wnkd34['BMI'],wnkd34.Extension,zorder=1,s=60,lw=2,marker='o',edgecolors='darkslategrey',facecolor='None',label='C3C4 Extension')
ax[2].scatter(wnkd56['BMI'],wnkd56.Extension,zorder=2,s=60,lw=2,marker='D',edgecolors='lightslategrey',facecolor='None',label='C5C6 Extension')
ax[2].scatter(wnkd34['BMI'],wnkd34.Flexion,zorder=3,s=60,lw=2,marker='o',edgecolors='darkviolet',facecolor='None',label='C3C4 Flexion')
ax[2].scatter(wnkd56['BMI'],wnkd56.Flexion,zorder=4,s=60,lw=2,marker='D',edgecolors='violet',facecolor='None',label='C5C6 Flexion')
ax[2].set_xlabel('BMI')
ax[2].set_title('BMI vs Rotation Angle')
ax[2].legend()

# %%
fig,ax=plt.subplots(2,3,figsize=(10,6),sharey='row',sharex='col')
fig.tight_layout()

ax[0][0].scatter(wnkd34['Weight (kg)'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[1][0].scatter(wnkd56['Weight (kg)'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[0][0].scatter(wnkd34['Weight (kg)'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][0].scatter(wnkd56['Weight (kg)'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][0].set_xlabel('Weight (kg)')
ax[0][0].set_ylabel('C3C4 - Rotation Angle')
ax[1][0].set_ylabel('C5C6 - Rotation Angle')
ax[0][0].set_title('Weight vs C3C4 Rotation')
ax[1][0].set_title('Weight vs C5C6 Rotation')

ax[0][1].scatter(wnkd34['Height (cm)'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[1][1].scatter(wnkd56['Height (cm)'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[0][1].scatter(wnkd34['Height (cm)'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][1].scatter(wnkd56['Height (cm)'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][1].set_xlabel('Height (cm)')
ax[0][1].set_title('Height vs C3C4 Rotation')
ax[1][1].set_title('Height vs C5C6 Rotation')

ax[0][2].scatter(wnkd34['BMI'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[1][2].scatter(wnkd56['BMI'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='lightslategrey',facecolor='None',label='Extension')
ax[0][2].scatter(wnkd34['BMI'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][2].scatter(wnkd56['BMI'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='lime',facecolor='None',label='Flexion')
ax[1][2].set_xlabel('BMI')
ax[0][2].set_title('BMI vs C3C4 Rotation')
ax[1][2].set_title('BMI vs C5C6 Rotation')
ax[0][0].legend()

# %%
fig,ax=plt.subplots(2,3,figsize=(10,6),sharey='row',sharex='col')
fig.tight_layout()

ax[0][0].scatter(wnkd34['Weight (kg)'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[0][0].scatter(wnkd56['Weight (kg)'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][0].scatter(wnkd34['Weight (kg)'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[1][0].scatter(wnkd56['Weight (kg)'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][0].set_xlabel('Weight (kg)')
ax[0][0].set_ylabel('Rotation Angle')
ax[1][0].set_ylabel('Rotation Angle')
ax[0][0].set_title('Weight vs Extension Angle')
ax[1][0].set_title('Weight vs Flexion Angle')

ax[0][1].scatter(wnkd34['Height (cm)'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[0][1].scatter(wnkd56['Height (cm)'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][1].scatter(wnkd34['Height (cm)'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[1][1].scatter(wnkd56['Height (cm)'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][1].set_xlabel('Height (cm)')
ax[0][1].set_title('Height vs Extension Angle')
ax[1][1].set_title('Height vs Flexion Angle')

ax[0][2].scatter(wnkd34['BMI'],wnkd34.Extension,zorder=1,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[0][2].scatter(wnkd56['BMI'],wnkd56.Extension,zorder=2,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][2].scatter(wnkd34['BMI'],wnkd34.Flexion,zorder=3,s=60,lw=2.5,edgecolors='hotpink',facecolor='None',label='C3C4')
ax[1][2].scatter(wnkd56['BMI'],wnkd56.Flexion,zorder=4,s=60,lw=2.5,edgecolors='dodgerblue',facecolor='None',label='C5C6')
ax[1][2].set_xlabel('BMI')
ax[0][2].set_title('BMI vs Extension Angle')
ax[1][2].set_title('BMI vs Flexion Angle')
ax[0][0].legend()

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -p pytensor,xarray
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Last updated: Thu Jun 05 2025
#
# Python implementation: CPython
# Python version       : 3.11.4
# IPython version      : 8.11.0
#
# pytensor: 2.25.4
# xarray  : 2024.5.0
#
# holoviews   : 1.19.1
# xarray      : 2024.5.0
# pandas      : 2.2.2
# great_tables: 0.15.0
# matplotlib  : 3.7.1
#
# Watermark: 2.4.3
